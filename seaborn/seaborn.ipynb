# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")   # seaborn load dataset in itself
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %% [markdown]
# scatter plot in seaborn

# %%
# plt.scatter()
sns.scatterplot(x="tip",y="total_bill",data=df)
plt.show()

# %% [markdown]
# sns.barplot()
# sns.histplot()
# ss.lineplot()
# sns.boxplot()
# sns.countplot()

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(df["day"])
plt.show()

# %%
sns.countplot(df["smoker"])
plt.show()

# %%
sns.countplot(df["sex"])
plt.show()

# %%
sns.countplot(df["total_bill"])
plt.show()

# %%
sns.countplot(df["time"])
plt.show()

# %% [markdown]
# (1) relplot= if both axis values are numerical
#
# (2) catplot= if only one axis value is numerical and one is catbolical

# %% [markdown]
# relplot = relational plot , by default scatter plot

# %%
sns.relplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="sex")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="smoker")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="sex",style="smoker")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="smoker",style="sex")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="sex",style="smoker",col="day")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="time",style="smoker",col="day")
plt.show()

# %%
sns.relplot(x="size",y="total_bill",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[["total_bill","tip","size"]].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="sex",kind="scatter")
plt.show()

# %%
sns.relplot(x="tip",y="total_bill",data=df,hue="sex",kind="line")
plt.show()

# %% [markdown]
# Catplot = One column is numerical and other is catbolical

# %%
sns.catplot(x="smoker",y="total_bill",data=df)

# %%
sns.catplot(x="total_bill",y="smoker",data=df)

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex")

# %%
sns.catplot(x="smoker",y="tip",data=df,hue="sex")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="box")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="violin")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="swarm")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="boxen")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="point")

# %%
sns.catplot(x="smoker",y="total_bill",data=df,hue="sex",kind="bar")

# %%
sns.catplot(x="smoker",data=df,kind="count")

# %%
sns.displot(df["total_bill"])
plt.show()

# %%
sns.histplot(df["total_bill"])
plt.show()

# %%
sns.displot(df["tip"])
plt.show()

# %%
sns.displot(df["smoker"])
plt.show()

# %%
sns.kdeplot(df["tip"])
plt.show()

# %%
sns.kdeplot(df["total_bill"],)
plt.show()

# %%
sns.displot(df["total_bill"],kde=True)
plt.show()

# %%
sns.displot(df["tip"],kde=True,color="r")
plt.show()

# %%
sns.displot(df["smoker"],kde=True,color="g")
plt.title("somke",color="r")
plt.show()

# %%
sns.displot(df["size"],kde=True,color="k",ec="r")

# %% [markdown]
# # Work On this both dataset below for practive

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.regplot(x="total_bill",y="tip",data=df)
plt.show()
